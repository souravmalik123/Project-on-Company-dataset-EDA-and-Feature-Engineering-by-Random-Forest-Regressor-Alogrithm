# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Load the Data Set

# %%
data = pd.read_csv("Company_Data.csv")

# %%
data.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
data.shape
# Out:
# (400, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    object
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    object
#  10  US           400 non-null    object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 34.5+ KB

# %%
data.describe()
# Out:
#             Sales   CompPrice      Income  Advertising  Population  \
# count  400.000000  400.000000  400.000000   400.000000  400.000000
# mean     7.496325  124.975000   68.657500     6.635000  264.840000
# std      2.824115   15.334512   27.986037     6.650364  147.376436
# min      0.000000   77.000000   21.000000     0.000000   10.000000
# 25%      5.390000  115.000000   42.750000     0.000000  139.000000
# 50%      7.490000  125.000000   69.000000     5.000000  272.000000
# 75%      9.320000  135.000000   91.000000    12.000000  398.500000
# max     16.270000  175.000000  120.000000    29.000000  509.000000
#
#             Price         Age   Education
# count  400.000000  400.000000  400.000000
# mean   115.795000   53.322500   13.900000
# std     23.676664   16.200297    2.620528
# min     24.000000   25.000000   10.000000
# 25%    100.000000   39.750000   12.000000
# 50%    117.000000   54.500000   14.000000
# 75%    131.000000   66.000000   16.000000
# ...

# %% [markdown]
# Missing values
#
# No Missing values in the dataset

# %%
data.isnull().sum()
# Out:
# Sales          0
# CompPrice      0
# Income         0
# Advertising    0
# Population     0
# Price          0
# ShelveLoc      0
# Age            0
# Education      0
# Urban          0
# US             0
# dtype: int64

# %%
data["Sales"].value_counts()
# Out:
# 7.80    4
# 8.77    3
# 9.32    3
# 4.10    3
# 6.20    3
#        ..
# 3.67    1
# 7.62    1
# 9.54    1
# 8.41    1
# 9.71    1
# Name: Sales, Length: 336, dtype: int64

# %%
sns.displot(x=data["Sales"],data=data)

# %%
data["CompPrice"].value_counts()
# Out:
# 121    16
# 122    14
# 131    14
# 123    13
# 115    12
#        ..
# 94      1
# 161     1
# 97      1
# 88      1
# 85      1
# Name: CompPrice, Length: 73, dtype: int64

# %%
sns.displot(x=data["CompPrice"],data=data)

# %%
sns.boxplot(x=data["CompPrice"]) ### Outliers in compPrice columns
# Out:
# <Axes: xlabel='CompPrice'>

# %%
data["Income"].unique()
# Out:
# array([ 73,  48,  35, 100,  64, 113, 105,  81, 110,  78,  94,  28, 117,
#         95,  32,  74,  76,  90,  29,  46,  31, 119, 115, 118,  99,  58,
#         38,  54,  84,  41,  60,  98,  53,  69,  42,  79,  63,  52,  93,
#         40, 103,  82,  91,  71, 102,  45,  88,  67,  26,  92,  61,  59,
#         51,  68, 111,  87,  72,  83,  36,  25,  66,  22,  30,  97,  77,
#         47,  96,  33, 107,  65,  62,  75,  89, 120,  34,  21,  39, 106,
#         24, 112,  37,  70,  80,  44, 104,  43,  56, 114,  57,  86,  50,
#         27, 101, 109,  55, 116, 108,  23], dtype=int64)

# %%
sns.displot(x=data["Income"],data=data)

# %%
sns.boxplot(x=data["Income"]) ### No Outlier in Income
# Out:
# <Axes: xlabel='Income'>

# %%
data["Advertising"].unique()
# Out:
# array([11, 16, 10,  4,  3, 13,  0, 15,  9,  2,  5, 12,  6, 14, 18, 19, 20,
#        23,  1,  7, 24,  8, 17, 25, 26, 29, 22, 21], dtype=int64)

# %%
sns.displot(x=data["Advertising"],data=data)

# %%
sns.boxplot(data["Advertising"]) ### No Outlier in Advertising
# Out:
# <Axes: >

# %%
data["Population"].unique()
# Out:
# array([276, 260, 269, 466, 340, 501,  45, 425, 108, 131, 150, 503, 393,
#         29, 148, 400, 284, 251, 408,  58, 367, 239, 497, 292, 294, 176,
#        496,  19, 359, 226, 447, 241, 236, 317, 406, 270, 412, 454, 144,
#         18, 403,  25,  16, 325, 168, 173, 349,  51, 341, 112,  39,  60,
#         54,  22, 188, 469, 358, 146, 170, 184, 197, 508, 152, 366, 339,
#        237, 432, 125, 480, 346,  44, 139, 286, 353, 468,  52, 304, 272,
#        493, 491, 267,  97,  67, 134, 407, 287, 382, 220,  94,  89,  57,
#        334, 472, 398, 217, 104, 488, 298, 335,  17,  95, 202, 507, 243,
#        137, 249, 380, 181, 192, 350, 279, 208, 232, 265, 327, 384,  10,
#        436, 371, 310, 277, 331, 300,  36, 264,  27, 402, 140, 289,  59,
#        189, 372, 486,  81, 424,  40, 100, 151, 216, 492, 356, 416, 123,
#        207,  38,  70, 434,  79, 230, 426,  35, 449,  93, 142, 509, 297,
#         71, 481, 420, 410, 333, 500, 413, 132, 326, 357, 445,  48, 156,
# ...

# %%
sns.displot(x=data["Population"],data=data)

# %%
sns.boxplot(x=data["Population"]) #### No Outlier in Population
# Out:
# <Axes: xlabel='Population'>

# %%
data["Price"].unique()
# Out:
# array([120,  83,  80,  97, 128,  72, 108, 124, 100,  94, 136,  86, 118,
#        144, 110, 131,  68, 121, 109, 138, 113,  82, 107, 102,  89, 137,
#         96, 126,  24, 134,  95, 135,  70,  98, 149, 129, 119, 154,  84,
#        117, 103, 114, 123, 133, 101, 104,  91, 115,  99, 150, 116,  92,
#        145,  90,  79, 139, 112, 111, 125, 148, 132, 127, 106, 151,  87,
#        155,  49, 147,  77, 159,  69, 157, 160, 141, 191,  93,  55, 185,
#        122,  81, 140, 173, 146, 130,  64, 105, 163,  88, 156, 166,  63,
#        158,  74,  54, 171, 152, 143, 164, 162,  53,  78], dtype=int64)

# %%
sns.displot(x=data["Price"],data=data)

# %%
sns.boxplot(x=data["Price"])  ### Outliers in the Price column
# Out:
# <Axes: xlabel='Price'>

# %%
data["ShelveLoc"].value_counts()
# Out:
# Medium    219
# Bad        96
# Good       85
# Name: ShelveLoc, dtype: int64

# %%
sns.countplot(x=data["ShelveLoc"],data=data)
# Out:
# <Axes: xlabel='ShelveLoc', ylabel='count'>

# %%
data["Age"].unique()
# Out:
# array([42, 65, 59, 55, 38, 78, 71, 67, 76, 26, 50, 62, 53, 52, 63, 46, 69,
#        35, 79, 54, 64, 58, 30, 44, 60, 73, 48, 32, 80, 75, 39, 61, 74, 29,
#        77, 56, 47, 25, 31, 36, 41, 68, 70, 28, 43, 49, 45, 33, 34, 51, 40,
#        72, 57, 27, 66, 37], dtype=int64)

# %%
sns.displot(x=data["Age"],data=data)

# %%
sns.boxplot(x=data["Age"])  ### No outliers in the Age column
# Out:
# <Axes: xlabel='Age'>

# %%
data["Education"].unique()
# Out:
# array([17, 10, 12, 14, 13, 16, 15, 18, 11], dtype=int64)

# %%
sns.countplot(x=data["Education"],data=data)
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
sns.boxplot(x=data["Education"])  #### No Outliers in the Education column
# Out:
# <Axes: xlabel='Education'>

# %%
data["Urban"].value_counts()
# Out:
# Yes    282
# No     118
# Name: Urban, dtype: int64

# %%
sns.countplot(x=data["Urban"],data=data)
# Out:
# <Axes: xlabel='Urban', ylabel='count'>

# %%
data["US"].value_counts()
# Out:
# Yes    258
# No     142
# Name: US, dtype: int64

# %%
sns.countplot(x=data["US"],data=data)
# Out:
# <Axes: xlabel='US', ylabel='count'>

# %%
data.corr()
# Out:
# C:\Users\MD SUHAIL MALIK\AppData\Local\Temp\ipykernel_14192\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                 Sales  CompPrice    Income  Advertising  Population     Price  \
# Sales        1.000000   0.064079  0.151951     0.269507    0.050471 -0.444951
# CompPrice    0.064079   1.000000 -0.080653    -0.024199   -0.094707  0.584848
# Income       0.151951  -0.080653  1.000000     0.058995   -0.007877 -0.056698
# Advertising  0.269507  -0.024199  0.058995     1.000000    0.265652  0.044537
# Population   0.050471  -0.094707 -0.007877     0.265652    1.000000 -0.012144
# Price       -0.444951   0.584848 -0.056698     0.044537   -0.012144  1.000000
# Age         -0.231815  -0.100239 -0.004670    -0.004557   -0.042663 -0.102177
# ...

# %%
sns.heatmap(data.corr(),annot=True,vmin=-1)
# Out:
# C:\Users\MD SUHAIL MALIK\AppData\Local\Temp\ipykernel_14192\1039722291.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True,vmin=-1)
# <Axes: >
